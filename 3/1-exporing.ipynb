# %%
import matplotlib.pyplot as plt, pandas as pd


# Prepare data for modeling
car_price = pd.read_csv("car_price_dataset.csv")
grouped = (car_price[["Brand", "Price"]]
           .groupby("Brand")
           .max()
           .sort_values(by="Price")
          )

plt.bar(grouped.index, grouped["Price"])

# Set title
plt.title("Brand/Cost")

# Set x-axis label
plt.xlabel("Brand")

# Set y-axis label
plt.ylabel("Maximum valuation in billions of dollars")

# Rotate labels on the x-axis as a way to avoid overlap in the positions of the text  
plt.xticks(rotation=45, horizontalalignment='right')

# Display the plot
plt.show()

# %%
# Reading a file, mode= 'r':reading, 'w':writing,
#  'a':appending, 'r+':reading and writing

with open('file_path/file_name', mode='r') as file:
    data = file.read()

# %%
#read csv
import pandas as pd

df = pd.read_csv('example_filepath/file')
